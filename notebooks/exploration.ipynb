# %%
import pandas as pd 
import matplotlib.pyplot as plt 

# Cargamos los datos limpios.

data_path = "../data/processed/cleaned_products.csv" 
df = pd.read_csv(data_path) 

# Analisis y visualizacion

print("Basic Statistics") 
print(df.describe()) 

# Histograma de precios.

plt.hist(df["Precio"], bins=20, edgecolor="black")
plt.title("Distribucion de precios") 
plt.xlabel("Precio") 
plt.ylabel("Frecuencia") 
plt.show() 

# Productos mas caros.

print("Productos mas Caros: ") 
highestPrice= df.nlargest(5,'Precio')
# Out:
# Basic Statistics
#             Precio
# count     5.000000
# mean    946.400000
# std     298.737008
# min     696.000000
# 25%     709.000000
# 50%     899.000000
# 75%     999.000000
# max    1429.000000
# Productos mas Caros:

# %%
print(highestPrice)
# Out:
#                                             Producto  Precio
# 0  Laptop Dell G15 5520 Gaming 165hz Win11 15.6 C...  1429.0
# 1         Laptop Dell G5 5500 Gaming Core I5 Android   999.0
# 2  Laptop Dell Inspiron Core I7 + 8gb Ram + 256gb...   899.0
# 3            Laptop Elitebook Touchscreen Win 10 Pro   709.0
# 4  Computadora Portátil, Core I7, 32gb Ram, 512gb...   696.0
